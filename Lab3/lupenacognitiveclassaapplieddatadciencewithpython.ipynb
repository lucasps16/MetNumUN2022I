# %% [markdown]
# ![Screenshot 2022-04-19 094510.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Screenshot 2022-04-19 094448.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Screenshot 2022-04-19 094426.jpg](data:image/jpeg;base64,...)
